# %% [markdown]
# # Tutorial: Preparing submission file and run evaluation for Task B
#
# In this notebook, a step-by-step tutorial is provided for preparing the submission file for the shared task Task B. To achieve this, the data for Task B, hosted on [Zenodo](https://doi.org/10.5281/zenodo.14002665), will be downloaded; a file with the appropriate [submission format](https://talentclef.github.io/talentclef/docs/talentclef-2025/evaluation/) will be prepared, and it will be evaluated using the [task's evaluation script](https://github.com/TalentCLEF/talentclef25_evaluation_script). Additionally, the provided format is also compatible with the benchmark where the test set data will be uploaded on Codabench.
#
#
#
# -----------------------------
# TalentCLEF is an initiative to advance Natural Language Processing (NLP) in Human Capital Management (HCM). It aims to create a public benchmark for model evaluation and promote collaboration to develop fair, multilingual, and flexible systems that improve Human Resources (HR) practices across different industries.
#
# This shared-task's inaugural edition is part of the [Conference and Labs of the Evaluation Forum (CLEF)](https://clef2025.clef-initiative.eu/index.php?page=Pages/labs.html), scheduled to be held in Madrid in 2025. If you are interested in registering, you can find registration form [here](https://clef2025-labs-registration.dei.unipd.it/).
#
# <img src="https://github.com/TalentCLEF/talentclef/blob/main/logo_talentclef.png?raw=true" alt="TalentCLEF logo" width="200"/>
# <img src="https://talentclef.github.io/talentclef/docs/talentclef-2025/workshop/logo_clef_madrid.png" alt="TalentCLEF logo" width="150"/>

# %% [markdown]
# ## Imports

# %%
import pandas as pd
import numpy as np
import json
from sentence_transformers import SentenceTransformer, util
import subprocess
from codecarbon import EmissionsTracker

# %%
import os
import sys

# %% [markdown]
# ## Download Task B files

# %% [markdown]
# First, let's download the Task A and Task B zip files directly from Zenodo.

# %%
# Download
# !wget https://zenodo.org/records/15038364/files/TaskB.zip
# !unzip TaskB.zip -d taskB

# %% [markdown]
# ## Generate releveant files using a simple model

# %% [markdown]
# **DE MOMENTO SUBIR LOS DATOS A MANOS HASTA EL RELEASE.**

# %%
taskB_path="/Users/zia-mac/Documents/projects/data/ir_data/talent_clef/TaskB"
taskB_validation_path=os.path.join(taskB_path, "validation")

# %%
taskB_models_path=os.path.join(taskB_path, "models")
taskB_results_path=os.path.join(taskB_path, "results")
taskB_evaluations_path=os.path.join(taskB_path, "evaluations")

model_name="all-MiniLM-L6-v2"
sentence_transformer_model=os.path.join(taskB_models_path, model_name)

# %% [markdown]
# Load queries and corpus elements in English from the Validation folder:

# %%
queries = os.path.join(taskB_validation_path, "queries")
corpus_elements = os.path.join(taskB_validation_path, "corpus_elements")

# %%
queries = pd.read_csv(queries,sep="\t")
corpus_elements = pd.read_csv(corpus_elements, sep="\t")

# %% [markdown]
# Transform `skill_aliases` column to a list of strings:

# %%
import ast
corpus_elements["skill_aliases"] = corpus_elements["skill_aliases"].apply(lambda x: ast.literal_eval(x))

# %% [markdown]
# Generate a mapping dictionary between IDs and texts from query and corpus element strings.

# %%
queries_ids = queries.q_id.to_list()
queries_texts = queries.jobtitle.to_list()
map_queries = dict(zip(queries_ids,queries_texts))

# %% [markdown]
# Before creating a mapping dictionary of texts to corpus_ids, explode the `skill_aliases` column:

# %%
list_aliases_df = corpus_elements.explode("skill_aliases")

# %%
corpus_ids = list_aliases_df.c_id.to_list()
corpus_texts = list_aliases_df.skill_aliases.to_list()
map_corpus = dict(zip(corpus_texts,corpus_ids))
map_corpus
# Out:
# {'pricing plans': 'dev_cb_sk_1',
#  'price strategies': 'dev_cb_sk_1',
#  'pricing tactics': 'dev_cb_sk_1',
#  'pricing strategies': 'dev_cb_sk_1',
#  'pricing strategy': 'dev_cb_sk_1',
#  'putting out fires': 'dev_cb_sk_2',
#  'put out fires': 'dev_cb_sk_2',
#  'extinguish fires': 'dev_cb_sk_2',
#  'fire extinguishing': 'dev_cb_sk_2',
#  'fires extinguishing': 'dev_cb_sk_2',
#  'extinguishing fires': 'dev_cb_sk_2',
#  'fire putting out': 'dev_cb_sk_2',
#  'fires putting out': 'dev_cb_sk_2',
#  'online assessment': 'dev_cb_sk_3',
#  'analysis of web strategy': 'dev_cb_sk_3',
#  'web presence assessment': 'dev_cb_sk_3',
#  'web strategy assessment': 'dev_cb_sk_3',
#  'keeping up with trends': 'dev_cb_sk_4',
#  'keep pace with trends': 'dev_cb_sk_4',
#  'follow trends': 'dev_cb_sk_4',
#  'keep up with a trend': 'dev_cb_sk_4',
#  'keeping up with a trend': 'dev_cb_sk_4',
#  'monitor trends': 'dev_cb_sk_4',
#  'keep up with trends': 'dev_cb_sk_4',
#  'prepare tax returns form': 'dev_cb_sk_5',
#  'complete tax returns forms': 'dev_cb_sk_5',
#  'prepare forms for tax returns': 'dev_cb_sk_5',
#  'prepare tax return forms': 'dev_cb_sk_5',
#  'get tax returns forms ready': 'dev_cb_sk_5',
#  'prepare tax returns forms': 'dev_cb_sk_5',
#  'make tax returns forms ready': 'dev_cb_sk_5',
#  'preparing tax returns forms': 'dev_cb_sk_5',
#  'tuning procedures': 'dev_cb_sk_6',
#  'tuning technique': 'dev_cb_sk_6',
#  'tuning routines': 'dev_cb_sk_6',
#  'tuning approaches': 'dev_cb_sk_6',
#  'techniques of tuning': 'dev_cb_sk_6',
#  'tuning skills': 'dev_cb_sk_6',
#  'tuning techniques': 'dev_cb_sk_6',
#  'iconography methods': 'dev_cb_sk_7',
#  'iconography': 'dev_cb_sk_7',
#  'teaching primary education class content': 'dev_cb_sk_8',
#  'educate on primary education class content': 'dev_cb_sk_8',
#  'explain primary education class content': 'dev_cb_sk_8',
#  'teaches primary education class content': 'dev_cb_sk_8',
#  'teach primary education class content': 'dev_cb_sk_8',
#  'provide instruction on primary education class content': 'dev_cb_sk_8',
#  'mobile operating systems': 'dev_cb_sk_9',
#  'cell phone  operating systems': 'dev_cb_sk_9',
#  'Ubuntu Touch OS': 'dev_cb_sk_9',
#  'Tizen': 'dev_cb_sk_9',
#  'Firefox OS': 'dev_cb_sk_9',
#  'Sailfish OS': 'dev_cb_sk_9',
#  'supervise sites maintenance': 'dev_cb_sk_10',
#  'manage site maintenance': 'dev_cb_sk_10',
#  'direct site maintenance': 'dev_cb_sk_10',
#  'organise site maintenance': 'dev_cb_sk_10',
#  'oversee site maintenance': 'dev_cb_sk_10',
#  'supervising site maintenance': 'dev_cb_sk_10',
#  'supervise site maintenance': 'dev_cb_sk_10',
#  'tracking methods': 'dev_cb_sk_11',
#  'animal tracking': 'dev_cb_sk_11',
#  'tracking principle': 'dev_cb_sk_11',
#  'tracking principles': 'dev_cb_sk_11',
#  'tracking approaches': 'dev_cb_sk_11',
#  'tracing principles': 'dev_cb_sk_11',
#  'tracking concepts': 'dev_cb_sk_11',
#  'performance diagnoses': 'dev_cb_sk_12',
#  'performance diagnosis': 'dev_cb_sk_12',
#  'improvement of performance level': 'dev_cb_sk_12',
#  'identification of individual performance levels': 'dev_cb_sk_12',
#  'diagnosis of performance': 'dev_cb_sk_12',
#  'improvement of performance levels': 'dev_cb_sk_12',
#  'cold-calling': 'dev_cb_sk_13',
#  'telemarketing': 'dev_cb_sk_13',
#  'telephone soliciting': 'dev_cb_sk_13',
#  'CPG': 'dev_cb_sk_14',
#  'consumer products industry': 'dev_cb_sk_14',
#  'consumer goods sector': 'dev_cb_sk_14',
#  'consumer goods industry': 'dev_cb_sk_14',
#  'consumer packaged goods': 'dev_cb_sk_14',
#  'striving for company growth': 'dev_cb_sk_15',
#  'strive for company growth': 'dev_cb_sk_15',
#  'strive growth of the company': 'dev_cb_sk_15',
#  'work hard for company growth': 'dev_cb_sk_15',
#  'crusade for  company growth': 'dev_cb_sk_15',
#  'video surveillance': 'dev_cb_sk_16',
#  'manage closed-circuit television system': 'dev_cb_sk_16',
#  'CCTV': 'dev_cb_sk_16',
#  'DBMS': 'dev_cb_sk_17',
#  'operate relational database management system': 'dev_cb_sk_17',
#  'corporate regulation': 'dev_cb_sk_18',
#  'corporation rules': 'dev_cb_sk_18',
#  'corporation regulation': 'dev_cb_sk_18',
#  'corporate law': 'dev_cb_sk_18',
#  'corporation statutes': 'dev_cb_sk_18',
#  'corporate statutes': 'dev_cb_sk_18',
#  'corporation law': 'dev_cb_sk_18',
#  'corporate rules': 'dev_cb_sk_18',
#  'write bill of materials': 'dev_cb_sk_19',
#  'write BOM': 'dev_cb_sk_19',
#  'BOM drafting': 'dev_cb_sk_19',
#  'writing BOM': 'dev_cb_sk_19',
#  'bill of material writing': 'dev_cb_sk_19',
#  'bill of material drafting': 'dev_cb_sk_19',
#  'BOM writing': 'dev_cb_sk_19',
#  'drafting BOM': 'dev_cb_sk_19',
#  'drafting bill of materials': 'dev_cb_sk_19',
#  'writing bill of materials': 'dev_cb_sk_19',
#  'draft bill of materials': 'dev_cb_sk_19',
#  'draft BOM': 'dev_cb_sk_19',
#  'customer insight': 'dev_cb_sk_20',
#  'customer insights': 'dev_cb_sk_20',
#  "customer's insight": 'dev_cb_sk_20',
#  'customers insight': 'dev_cb_sk_20',
#  'customer understanding': 'dev_cb_sk_20',
#  'labelling components': 'dev_cb_sk_21',
#  'label goods': 'dev_cb_sk_21',
#  'label components': 'dev_cb_sk_21',
#  'label accessories': 'dev_cb_sk_21',
#  'label parts': 'dev_cb_sk_21',
#  'label a component': 'dev_cb_sk_21',
#  'label materials': 'dev_cb_sk_21',
#  'ensure environmental protection in work practices': 'dev_cb_sk_22',
#  'facilitate environmentally friendly work practices': 'dev_cb_sk_22',
#  'apply criteria to prevent damage to the environment': 'dev_cb_sk_22',
#  'implement environmental protection criteria': 'dev_cb_sk_22',
#  'enforce environmental protection measures': 'dev_cb_sk_22',
#  'apply measures to prevent damage to the environment': 'dev_cb_sk_22',
#  'enforce environmental protection criteria': 'dev_cb_sk_22',
#  'implement environmental protection measures': 'dev_cb_sk_22',
#  'administer environmental protection measures': 'dev_cb_sk_22',
#  'communicate with policymakers to influence policies': 'dev_cb_sk_23',
#  'convince policymakers to change policies': 'dev_cb_sk_23',
#  'influence public policies': 'dev_cb_sk_23',
#  'communicate with policymakers for lobbying purposes': 'dev_cb_sk_23',
#  'lobbying for public policies': 'dev_cb_sk_23',
#  'communicate with policymakers for lobbying aims': 'dev_cb_sk_23',
#  'research website traffic': 'dev_cb_sk_24',
#  'perform website user base research activities': 'dev_cb_sk_24',
#  'research online user base': 'dev_cb_sk_24',
#  'conduct research into the needs of website users': 'dev_cb_sk_24',
#  'analyse traffic and user base of website': 'dev_cb_sk_24',
#  'research users of website': 'dev_cb_sk_24',
#  'identify needs of website users to increase traffic': 'dev_cb_sk_24',
#  'research website users and traffic': 'dev_cb_sk_24',
#  'research website user base': 'dev_cb_sk_24',
#  'analyse and identify needs of website users to increase traffic': 'dev_cb_sk_24',
#  'analyse website users to increase traffic': 'dev_cb_sk_24',
#  'research user base of website': 'dev_cb_sk_24',
#  'research website users': 'dev_cb_sk_24',
#  'foot disorders': 'dev_cb_sk_25',
#  'foot issues': 'dev_cb_sk_25',
#  'foot problem': 'dev_cb_sk_25',
#  'foot difficulties': 'dev_cb_sk_25',
#  'pain of the feet': 'dev_cb_sk_25',
#  'foot difficulty': 'dev_cb_sk_25',
#  'foot issue': 'dev_cb_sk_25',
#  'difficulties with feet': 'dev_cb_sk_25',
#  'foot pain': 'dev_cb_sk_25',
#  'foot problems': 'dev_cb_sk_25',
#  'develop animated models': 'dev_cb_sk_26',
#  'design graphics and animation': 'dev_cb_sk_26',
#  'develop animations': 'dev_cb_sk_26',
#  'developing animations': 'dev_cb_sk_26',
#  'design animations': 'dev_cb_sk_26',
#  'develop an animation': 'dev_cb_sk_26',
#  'range of precision manufacturing instruments': 'dev_cb_sk_27',
#  'instrument for precision measuring': 'dev_cb_sk_27',
#  'types of precision manufacturing instrument': 'dev_cb_sk_27',
#  'kinds of precision measuring instrument': 'dev_cb_sk_27',
#  'types of precision measuring instrument': 'dev_cb_sk_27',
#  'instrument for precision manufacturing': 'dev_cb_sk_27',
#  'precision measuring instruments': 'dev_cb_sk_27',
#  'instrument for precision measurement': 'dev_cb_sk_27',
#  'range of precision measuring instruments': 'dev_cb_sk_27',
#  'kinds of precision manufacturing instrument': 'dev_cb_sk_27',
#  'investigation research plans': 'dev_cb_sk_28',
#  'investigation research arrangements': 'dev_cb_sk_28',
#  'investigation survey processes': 'dev_cb_sk_28',
#  'investigation research processes': 'dev_cb_sk_28',
#  'investigation research methods': 'dev_cb_sk_28',
#  'investigation survey arrangements': 'dev_cb_sk_28',
#  'investigation survey plans': 'dev_cb_sk_28',
#  'investigation survey approaches': 'dev_cb_sk_28',
#  'investigation research approaches': 'dev_cb_sk_28',
#  'motivate employee': 'dev_cb_sk_29',
#  'inspire employees': 'dev_cb_sk_29',
#  'motivating employees': 'dev_cb_sk_29',
#  'motivate employees': 'dev_cb_sk_29',
#  'encourage employees': 'dev_cb_sk_29',
#  'stimulate employees': 'dev_cb_sk_29',
#  'motivate workers': 'dev_cb_sk_29',
#  'agree on products to be stocked': 'dev_cb_sk_30',
#  'determine products to be stocked': 'dev_cb_sk_30',
#  'deciding on products to be stocked': 'dev_cb_sk_30',
#  'select products to be stocked': 'dev_cb_sk_30',
#  'decide on the products to be stocked': 'dev_cb_sk_30',
#  'decide on products to be stocked': 'dev_cb_sk_30',
#  'decide on a product to be stocked': 'dev_cb_sk_30',
#  'choose products to be stocked': 'dev_cb_sk_30',
#  'decrease in value': 'dev_cb_sk_31',
#  'devaluation': 'dev_cb_sk_31',
#  'depreciation': 'dev_cb_sk_31',
#  'review information systems': 'dev_cb_sk_32',
#  'analyse information systems': 'dev_cb_sk_32',
#  'analysing information systems': 'dev_cb_sk_32',
#  'analyse info systems': 'dev_cb_sk_32',
#  'analyse information system': 'dev_cb_sk_32',
#  'analyze  information systems': 'dev_cb_sk_32',
#  'examine information systems': 'dev_cb_sk_32',
#  'evaluate information systems': 'dev_cb_sk_32',
#  'website marketing': 'dev_cb_sk_33',
#  'enhance website visibility': 'dev_cb_sk_33',
#  'electricity principles': 'dev_cb_sk_34',
#  'electrical current': 'dev_cb_sk_34',
#  'resistance': 'dev_cb_sk_34',
#  'physics of electricity': 'dev_cb_sk_34',
#  'science of electricity': 'dev_cb_sk_34',
#  'current': 'dev_cb_sk_34',
#  'voltage': 'dev_cb_sk_34',
#  'principles of electricity': 'dev_cb_sk_34',
#  'theory of electricity': 'dev_cb_sk_34',
#  'read circuit diagrams': 'dev_cb_sk_35',
#  'interpret circuit diagrams': 'dev_cb_sk_35',
#  'understand circuit blueprints': 'dev_cb_sk_35',
#  'understand circuit schematics': 'dev_cb_sk_35',
#  'read diagrams of circuits': 'dev_cb_sk_35',
#  'interpret electrical circuit diagrams': 'dev_cb_sk_35',
#  'interpret elementary diagrams': 'dev_cb_sk_35',
#  'possess emotional intelligence': 'dev_cb_sk_36',
#  "recognize other people's emotions": 'dev_cb_sk_36',
#  'own emotional intelligence': 'dev_cb_sk_36',
#  "recognize other people's emotion": 'dev_cb_sk_36',
#  'have emotional intelligence': 'dev_cb_sk_36',
#  'obtain emotional intelligence': 'dev_cb_sk_36',
#  'cadastral taxation': 'dev_cb_sk_37',
#  'cadastral income': 'dev_cb_sk_37',
#  'cadastral revenues': 'dev_cb_sk_37',
#  'real estate taxes': 'dev_cb_sk_37',
#  'real estate revenues': 'dev_cb_sk_37',
#  'real estate income': 'dev_cb_sk_37',
#  'cadastral taxes': 'dev_cb_sk_37',
#  'cyber security frameworks': 'dev_cb_sk_38',
#  'information security compliances': 'dev_cb_sk_38',
#  'ICT security compliances': 'dev_cb_sk_38',
#  'IT security standards': 'dev_cb_sk_38',
#  'cyber security compliances': 'dev_cb_sk_38',
#  'cyber security standards': 'dev_cb_sk_38',
#  'information security standards': 'dev_cb_sk_38',
#  'IT security compliances': 'dev_cb_sk_38',
#  'ICT security frameworks': 'dev_cb_sk_38',
#  'IT security frameworks': 'dev_cb_sk_38',
#  'ICT security standards': 'dev_cb_sk_38',
#  'information security frameworks': 'dev_cb_sk_38',
#  'accounting': 'dev_cb_sk_39',
#  'bookkeeping': 'dev_cb_sk_39',
#  'managing payroll': 'dev_cb_sk_40',
#  'administer payroll': 'dev_cb_sk_40',
#  'handle payroll': 'dev_cb_sk_40',
#  'oversee payroll': 'dev_cb_sk_40',
#  'manage payroll': 'dev_cb_sk_40',
#  'incorporate community activities': 'dev_cb_sk_41',
#  'integrate the community outreach': 'dev_cb_sk_41',
#  'combine community outreach': 'dev_cb_sk_41',
#  'integrate community outreach': 'dev_cb_sk_41',
#  'participate in multimedia campaigns': 'dev_cb_sk_42',
#  'participate in design of multimedia campaigns': 'dev_cb_sk_42',
#  'design materials for campaigns': 'dev_cb_sk_42',
#  'design materials for campaigns in multimedia': 'dev_cb_sk_42',
#  'design multimedia campaign materials': 'dev_cb_sk_42',
#  'design materials for multimedia campaigns': 'dev_cb_sk_42',
#  'Open source model': 'dev_cb_sk_43',
#  '5S methodology for workplace organisation': 'dev_cb_sk_44',
#  '5S methodology to reduce waste in the workplace': 'dev_cb_sk_44',
#  '5S workplace organization method': 'dev_cb_sk_44',
#  '5S methods for workplace organisation': 'dev_cb_sk_44',
#  '5S methodology': 'dev_cb_sk_44',
#  '5S workplace organisation method': 'dev_cb_sk_44',
#  'community law': 'dev_cb_sk_45',
#  'European Union law': 'dev_cb_sk_45',
#  'EU legislation': 'dev_cb_sk_45',
#  'EU law': 'dev_cb_sk_45',
#  'ABAP': 'dev_cb_sk_46',
#  'providing ICT support': 'dev_cb_sk_47',
#  'contribute ICT support': 'dev_cb_sk_47',
#  'ICT support provision': 'dev_cb_sk_47',
#  'arrange ICT support': 'dev_cb_sk_47',
#  'provision of ICT support': 'dev_cb_sk_47',
#  'furnish ICT support': 'dev_cb_sk_47',
#  'administer ICT support': 'dev_cb_sk_47',
#  'provide ICT support': 'dev_cb_sk_47',
#  'pipeline types': 'dev_cb_sk_48',
#  'varieties of transportation pipelines': 'dev_cb_sk_48',
#  'classifications of transport pipelines': 'dev_cb_sk_48',
#  'kinds of pipeline': 'dev_cb_sk_48',
#  'categories of pipeline': 'dev_cb_sk_48',
#  'types of pipelines': 'dev_cb_sk_48',
#  'class of pipeline': 'dev_cb_sk_48',
#  'forms of pipeline': 'dev_cb_sk_48',
#  'differences between pipeline types': 'dev_cb_sk_48',
#  'pipeline classifications': 'dev_cb_sk_48',
#  'do cost accounting activities': 'dev_cb_sk_49',
#  'performing cost accounting activities': 'dev_cb_sk_49',
#  'conduct cost accounting activities': 'dev_cb_sk_49',
#  'perform cost accounting activity': 'dev_cb_sk_49',
#  'perform cost accounting activities': 'dev_cb_sk_49',
#  'perform activities for cost accounting': 'dev_cb_sk_49',
#  'do the dishes': 'dev_cb_sk_50',
#  'clean up the dishes': 'dev_cb_sk_50',
#  'use the dishwashing machine': 'dev_cb_sk_50',
#  'wash the dishes': 'dev_cb_sk_50',
#  'washing the dishes': 'dev_cb_sk_50',
#  'demonstrate concern for others': 'dev_cb_sk_51',
#  'concern for others': 'dev_cb_sk_51',
#  'communicate an empathic response': 'dev_cb_sk_51',
#  'show concern for others': 'dev_cb_sk_51',
#  'exhibit consideration': 'dev_cb_sk_51',
#  'show courtesy': 'dev_cb_sk_51',
#  'be empathic': 'dev_cb_sk_51',
#  'show empathy': 'dev_cb_sk_51',
#  'demonstrate consideration': 'dev_cb_sk_51',
#  'treat people fairly': 'dev_cb_sk_51',
#  'show good manners': 'dev_cb_sk_51',
#  'showing empathy': 'dev_cb_sk_51',
#  'display consideration': 'dev_cb_sk_51',
#  'communicate messages through radio and telephone systems': 'dev_cb_sk_52',
#  'communicate messages via radio and telephone systems': 'dev_cb_sk_52',
#  'pass messages through radio and telephone systems': 'dev_cb_sk_52',
#  'communicate using radio and telephone systems': 'dev_cb_sk_52',
#  'relay messages through radio and telephone systems': 'dev_cb_sk_52',
#  'communicate using radio systems': 'dev_cb_sk_52',
#  'relay messages via radio and telephone systems': 'dev_cb_sk_52',
#  'pass messages via radio and telephone systems': 'dev_cb_sk_52',
#  'utilise communication skills to relay messages using radio and telephone equipment': 'dev_cb_sk_52',
#  'use communication skills to relay messages through radio and telephone systems': 'dev_cb_sk_52',
#  'assess economic movements': 'dev_cb_sk_53',
#  'scrutinise economic movements': 'dev_cb_sk_53',
#  'analyze  economic trends': 'dev_cb_sk_53',
#  'analyse economic trends': 'dev_cb_sk_53',
#  'investigate economic trends': 'dev_cb_sk_53',
#  'test economic movements': 'dev_cb_sk_53',
#  'investigate economic movements': 'dev_cb_sk_53',
#  'scrutinise economic trends': 'dev_cb_sk_53',
#  'test economic trends': 'dev_cb_sk_53',
#  'assess economic trends': 'dev_cb_sk_53',
#  'data processing': 'dev_cb_sk_54',
#  'process data': 'dev_cb_sk_54',
#  'processing of data': 'dev_cb_sk_54',
#  'processing data': 'dev_cb_sk_54',
#  'handle data': 'dev_cb_sk_54',
#  'refine data': 'dev_cb_sk_54',
#  'analyse data': 'dev_cb_sk_54',
#  'measure data': 'dev_cb_sk_54',
#  'convert data': 'dev_cb_sk_54',
#  'uncover acting talent': 'dev_cb_sk_55',
#  'identify acting talent': 'dev_cb_sk_55',
#  'discover acting talent': 'dev_cb_sk_55',
#  'find acting talent': 'dev_cb_sk_55',
#  'discovering acting talent': 'dev_cb_sk_55',
#  'discover acting talents': 'dev_cb_sk_55',
#  'trade bonds': 'dev_cb_sk_56',
#  'deal in securities': 'dev_cb_sk_56',
#  'sell securities': 'dev_cb_sk_56',
#  'market securities': 'dev_cb_sk_56',
#  'trade equities': 'dev_cb_sk_56',
#  'trade securities': 'dev_cb_sk_56',
#  'customer experience management': 'dev_cb_sk_57',
#  "manage customers' experience": 'dev_cb_sk_57',
#  'manage the customer experience': 'dev_cb_sk_57',
#  'contribute to a customer experience': 'dev_cb_sk_57',
#  'manage customer experience': 'dev_cb_sk_57',
#  'estimation of profitability': 'dev_cb_sk_58',
#  'estimate profitability': 'dev_cb_sk_58',
#  'evaluation of profitability': 'dev_cb_sk_58',
#  'profitability estimating': 'dev_cb_sk_58',
#  'estimating profitability': 'dev_cb_sk_58',
#  'estimating profit': 'dev_cb_sk_58',
#  'evaluation of profit': 'dev_cb_sk_58',
#  'estimation of profit': 'dev_cb_sk_58',
#  'evaluating profitability': 'dev_cb_sk_58',
#  'evaluating profit': 'dev_cb_sk_58',
#  'evaluate profitability': 'dev_cb_sk_58',
#  'evaluate profit': 'dev_cb_sk_58',
#  'profit estimating': 'dev_cb_sk_58',
#  'estimate profit': 'dev_cb_sk_58',
#  'civil engineering work': 'dev_cb_sk_59',
#  'civil engineering analysis': 'dev_cb_sk_59',
#  'civil engineering applications': 'dev_cb_sk_59',
#  'civil engineering analyses': 'dev_cb_sk_59',
#  'civil engineering fieldwork': 'dev_cb_sk_59',
#  'civil engineering research': 'dev_cb_sk_59',
#  'civil engineering': 'dev_cb_sk_59',
#  'city planning': 'dev_cb_sk_59',
#  'civil engineering studies': 'dev_cb_sk_59',
#  'maintain IP configuration': 'dev_cb_sk_60',
#  'apply Internet Protocol Configuration': 'dev_cb_sk_60',
#  'maintain internet protocol configuration': 'dev_cb_sk_60',
#  'property legislation': 'dev_cb_sk_61',
#  'real property law': 'dev_cb_sk_61',
#  'property contract rules': 'dev_cb_sk_61',
#  'real estate law': 'dev_cb_sk_61',
#  'property law': 'dev_cb_sk_61',
#  'Live Script': 'dev_cb_sk_62',
#  'Mocha': 'dev_cb_sk_62',
#  'JavaScript': 'dev_cb_sk_62',
#  'Client-side JavaScript': 'dev_cb_sk_62',
#  'Server-side JavaScript': 'dev_cb_sk_62',
#  'Escript': 'dev_cb_sk_62',
#  'CSJS': 'dev_cb_sk_62',
#  'visualise completed work': 'dev_cb_sk_63',
#  'work conceptually': 'dev_cb_sk_63',
#  'show originality': 'dev_cb_sk_63',
#  'find new ideas': 'dev_cb_sk_63',
#  'visualise completed project': 'dev_cb_sk_63',
#  'thinking creatively': 'dev_cb_sk_63',
#  'experiment': 'dev_cb_sk_63',
#  'use imagination': 'dev_cb_sk_63',
#  'design': 'dev_cb_sk_63',
#  'anticipate needs': 'dev_cb_sk_63',
#  'think creatively': 'dev_cb_sk_63',
#  'seek out questions': 'dev_cb_sk_63',
#  'innovative thinking': 'dev_cb_sk_63',
#  'brainstorming': 'dev_cb_sk_63',
#  'innovate': 'dev_cb_sk_63',
#  'think in a creative way': 'dev_cb_sk_63',
#  'providing library information': 'dev_cb_sk_64',
#  'make library information available': 'dev_cb_sk_64',
#  'provide library info': 'dev_cb_sk_64',
#  'supply library information': 'dev_cb_sk_64',
#  'provide library information': 'dev_cb_sk_64',
#  'distribute library information': 'dev_cb_sk_64',
#  'using construction tools': 'dev_cb_sk_65',
#  'using construction and repair tools': 'dev_cb_sk_65',
#  'use repair tools': 'dev_cb_sk_65',
#  'using repair tools': 'dev_cb_sk_65',
#  'employ repair tools': 'dev_cb_sk_65',
#  'use construction and repair tools': 'dev_cb_sk_65',
#  'employing construction and repair tools': 'dev_cb_sk_65',
#  'employ tools for construction and repair': 'dev_cb_sk_65',
#  'employ construction and repair tools': 'dev_cb_sk_65',
#  'employing repair tools': 'dev_cb_sk_65',
#  'use construction tools': 'dev_cb_sk_65',
#  'use tools for construction and repair': 'dev_cb_sk_65',
#  'employing tools for construction and repair': 'dev_cb_sk_65',
#  'employ construction tools': 'dev_cb_sk_65',
#  'employing construction tools': 'dev_cb_sk_65',
#  'prepare auxiliary equipment and main engines for operations': 'dev_cb_sk_66',
#  'get engine room ready': 'dev_cb_sk_66',
#  'ready main engines and auxiliary equipment': 'dev_cb_sk_66',
#  'ready engine room for operations': 'dev_cb_sk_66',
#  'prepare main engines and auxiliary equipment': 'dev_cb_sk_66',
#  'make engine room ready for operations': 'dev_cb_sk_66',
#  'prepare engine room for operations': 'dev_cb_sk_66',
#  'prepare engine room': 'dev_cb_sk_66',
#  'ready auxiliary equipment and main engines': 'dev_cb_sk_66',
#  'prepare main engine and auxiliary equipment for operation': 'dev_cb_sk_66',
#  'prepare engine room for operation': 'dev_cb_sk_66',
#  'make engine room ready': 'dev_cb_sk_66',
#  'get engine room ready for operations': 'dev_cb_sk_66',
#  'exceed customer expectations in the provision of services': 'dev_cb_sk_67',
#  'deliver outstanding service to customers': 'dev_cb_sk_67',
#  'exceed customer expectations in service provision': 'dev_cb_sk_67',
#  'ensure customers receive outstanding service': 'dev_cb_sk_67',
#  'ensure customers receive an outstanding service': 'dev_cb_sk_67',
#  'deliver outstanding service': 'dev_cb_sk_67',
#  'provide outstanding service': 'dev_cb_sk_67',
#  'provide outstanding service to customers': 'dev_cb_sk_67',
#  'ensure customers receive an exceptional service': 'dev_cb_sk_67',
#  'provide outstanding customer service': 'dev_cb_sk_67',
#  'supply outstanding customer service': 'dev_cb_sk_67',
#  'deliver outstanding customer service': 'dev_cb_sk_67',
#  'green technologies': 'dev_cb_sk_68',
#  'alternative energy': 'dev_cb_sk_68',
#  'sustainable technologies': 'dev_cb_sk_68',
#  'clean energy': 'dev_cb_sk_68',
#  'insurance legislation': 'dev_cb_sk_69',
#  'insurance law': 'dev_cb_sk_69',
#  'insurance regulations': 'dev_cb_sk_69',
#  'regulations concerning insurance policies': 'dev_cb_sk_69',
#  'law concerning insurance policies': 'dev_cb_sk_69',
#  'communicate with brokers': 'dev_cb_sk_70',
#  'communicate with financiers': 'dev_cb_sk_70',
#  'communicate with professional bankers': 'dev_cb_sk_70',
#  'communicate with banking professionals': 'dev_cb_sk_70',
#  'communicate with bankers': 'dev_cb_sk_70',
#  'communicate with investors': 'dev_cb_sk_70',
#  'advertising skills': 'dev_cb_sk_71',
#  'advertising performance': 'dev_cb_sk_71',
#  'an advertising techniques': 'dev_cb_sk_71',
#  'advertising approaches': 'dev_cb_sk_71',
#  'advertising technique': 'dev_cb_sk_71',
#  'advertising techniques': 'dev_cb_sk_71',
#  'advertising methods': 'dev_cb_sk_71',
#  'techniques of advertising': 'dev_cb_sk_71',
#  'produce business relationships': 'dev_cb_sk_72',
#  'assemble business relationships': 'dev_cb_sk_72',
#  'construct business relationships': 'dev_cb_sk_72',
#  'devise business relationships': 'dev_cb_sk_72',
#  'building business relationships': 'dev_cb_sk_72',
#  'build a business relationship': 'dev_cb_sk_72',
#  'build business relationships': 'dev_cb_sk_72',
#  'set up business relationships': 'dev_cb_sk_72',
#  'analysis of the market': 'dev_cb_sk_73',
#  'marketing analysis': 'dev_cb_sk_73',
#  'market analysis': 'dev_cb_sk_73',
#  'carry out measurements': 'dev_cb_sk_74',
#  'demonstrate technical abilities': 'dev_cb_sk_74',
#  'apply knowledge of science, technology and engineering': 'dev_cb_sk_74',
#  'demonstrate scientific literacy': 'dev_cb_sk_74',
#  'take on new technology': 'dev_cb_sk_74',
#  'represent members and union': 'dev_cb_sk_75',
#  'act for union members': 'dev_cb_sk_75',
#  'speak for workforce members': 'dev_cb_sk_75',
#  'act for workforce members': 'dev_cb_sk_75',
#  'speak on behalf of union members': 'dev_cb_sk_75',
#  'serve workforce members': 'dev_cb_sk_75',
#  'speak for union members': 'dev_cb_sk_75',
#  'represent union members': 'dev_cb_sk_75',
#  'serve union members': 'dev_cb_sk_75',
#  'speak on behalf of workforce members': 'dev_cb_sk_75',
#  'deliver online training': 'dev_cb_sk_76',
#  'electrical appliances products for a household': 'dev_cb_sk_77',
#  'electrical household appliances goods': 'dev_cb_sk_77',
#  'an electrical household appliances product': 'dev_cb_sk_77',
#  'electrical household appliances brands': 'dev_cb_sk_77',
#  'electrical household appliances commodities': 'dev_cb_sk_77',
#  'electrical household appliances merchandise': 'dev_cb_sk_77',
#  'an electrical household appliance product': 'dev_cb_sk_77',
#  'electrical household appliances products': 'dev_cb_sk_77',
#  'electrical household appliances stock': 'dev_cb_sk_77',
#  'social services': 'dev_cb_sk_78',
#  'clinical social work': 'dev_cb_sk_78',
#  'continuous improvement systems': 'dev_cb_sk_79',
#  'continuous improvement philosophies': 'dev_cb_sk_79',
#  'a continuous improvement philosophy': 'dev_cb_sk_79',
#  'continuous improvement philosophy': 'dev_cb_sk_79',
#  'continuous improvement policies': 'dev_cb_sk_79',
#  'continuous improvement processes': 'dev_cb_sk_79',
#  'continuous improvement strategies': 'dev_cb_sk_79',
#  'processor': 'dev_cb_sk_80',
#  'security system panels': 'dev_cb_sk_80',
#  'components of security panel': 'dev_cb_sk_80',
#  'motherboard': 'dev_cb_sk_80',
#  'wire contact points': 'dev_cb_sk_80',
#  'transformer': 'dev_cb_sk_80',
#  'security panels': 'dev_cb_sk_80',
#  'security panel components': 'dev_cb_sk_80',
#  'Data Migrator': 'dev_cb_sk_81',
#  'Elixir Repertoire for Data ETL': 'dev_cb_sk_81',
#  'Talend Studio for Data Integration': 'dev_cb_sk_81',
#  'Relational Junction ETL Manager': 'dev_cb_sk_81',
#  'Syncsort DMX': 'dev_cb_sk_81',
#  'IBM Infosphere WarehoEdition': 'dev_cb_sk_81',
#  'Adeptia Integration Server': 'dev_cb_sk_81',
#  'Centerprise Data Integrator': 'dev_cb_sk_81',
#  'data extraction, transformation and loading tools': 'dev_cb_sk_81',
#  'PowerCenter Informatica': 'dev_cb_sk_81',
#  'CloverETL': 'dev_cb_sk_81',
#  'Cognos Data Manager': 'dev_cb_sk_81',
#  'Pervasive Data Integrator': 'dev_cb_sk_81',
#  'Sagent Data Flow': 'dev_cb_sk_81',
#  'ETL': 'dev_cb_sk_81',
#  'Open Text Integration Center': 'dev_cb_sk_81',
#  'overseeing cultivation technical equipment': 'dev_cb_sk_82',
#  'maintaining cultivation technical equipment': 'dev_cb_sk_82',
#  'maintain technical equipment': 'dev_cb_sk_82',
#  'cultivation technical equipment maintaining': 'dev_cb_sk_82',
#  'oversee cultivation technical equipment': 'dev_cb_sk_82',
#  'maintain cultivation technical equipment': 'dev_cb_sk_82',
#  'overseeing technical equipment': 'dev_cb_sk_82',
#  'technical equipment maintaining': 'dev_cb_sk_82',
#  'maintaining technical equipment': 'dev_cb_sk_82',
#  'technical equipment overseeing': 'dev_cb_sk_82',
#  'oversee technical equipment': 'dev_cb_sk_82',
#  'cultivation technical equipment overseeing': 'dev_cb_sk_82',
#  'take affidavit': 'dev_cb_sk_83',
#  'do affidavits': 'dev_cb_sk_83',
#  'take affidavits': 'dev_cb_sk_83',
#  'taking affidavits': 'dev_cb_sk_83',
#  'principles of ecological agriculture': 'dev_cb_sk_84',
#  'principles of organic farming': 'dev_cb_sk_84',
#  'types of organic farming': 'dev_cb_sk_84',
#  'typology of ecological agriculture': 'dev_cb_sk_84',
#  'farming ecologically': 'dev_cb_sk_84',
#  'regulations of ecological agriculture': 'dev_cb_sk_84',
#  'types of ecological agriculture': 'dev_cb_sk_84',
#  'regulations of organic farming': 'dev_cb_sk_84',
#  'typology of organic farming': 'dev_cb_sk_84',
#  'organic farming': 'dev_cb_sk_84',
#  'farming organically': 'dev_cb_sk_84',
#  'prepared pizza': 'dev_cb_sk_85',
#  'prepare pizza': 'dev_cb_sk_85',
#  'cook and serve pizza': 'dev_cb_sk_85',
#  'create pizza': 'dev_cb_sk_85',
#  'prepare pizzas': 'dev_cb_sk_85',
#  'oversee tests': 'dev_cb_sk_86',
#  'oversee exams': 'dev_cb_sk_86',
#  'manage tests': 'dev_cb_sk_86',
#  'oversee examinations': 'dev_cb_sk_86',
#  'manage test': 'dev_cb_sk_86',
#  'manage exams': 'dev_cb_sk_86',
#  'supervise tests': 'dev_cb_sk_86',
#  'managing tests': 'dev_cb_sk_86',
#  'supervise exams': 'dev_cb_sk_86',
#  'supervise examinations': 'dev_cb_sk_86',
#  'manage examinations': 'dev_cb_sk_86',
#  'window assembling': 'dev_cb_sk_87',
#  'window making': 'dev_cb_sk_87',
#  'making windows': 'dev_cb_sk_87',
#  'assemble windows': 'dev_cb_sk_87',
#  'make windows': 'dev_cb_sk_87',
#  'assembling windows': 'dev_cb_sk_87',
#  'welcome guests at restaurant': 'dev_cb_sk_88',
#  'greet and accompany guests to tables': 'dev_cb_sk_88',
#  'welcome guests in restaurant': 'dev_cb_sk_88',
#  'welcome restaurant guests': 'dev_cb_sk_88',
#  'greet clients and usher them to their table': 'dev_cb_sk_88',
#  'a business management principle': 'dev_cb_sk_89',
#  'business management foundations': 'dev_cb_sk_89',
#  'principles of business management': 'dev_cb_sk_89',
#  'business management conventions': 'dev_cb_sk_89',
#  'business management principles': 'dev_cb_sk_89',
#  'business management principle': 'dev_cb_sk_89',
#  'business management fundamentals': 'dev_cb_sk_89',
#  'business management standards': 'dev_cb_sk_89',
#  'application development life-cycle': 'dev_cb_sk_90',
#  'systems development life-cycle': 'dev_cb_sk_90',
#  'manage audit': 'dev_cb_sk_91',
#  'arrange audits': 'dev_cb_sk_91',
#  'arrange audit': 'dev_cb_sk_91',
#  'plan audit': 'dev_cb_sk_91',
#  'organise audit': 'dev_cb_sk_91',
#  'prepare audit': 'dev_cb_sk_91',
#  'arranging audit': 'dev_cb_sk_91',
#  'pick an order for dispatching': 'dev_cb_sk_92',
#  'pick orders for dispatching': 'dev_cb_sk_92',
#  'purchase orders for dispatching': 'dev_cb_sk_92',
#  'buy orders for dispatching': 'dev_cb_sk_92',
#  'pick orders for dispatch': 'dev_cb_sk_92',
#  'get orders for dispatching': 'dev_cb_sk_92',
#  'picking orders for dispatching': 'dev_cb_sk_92',
#  'create artwork': 'dev_cb_sk_93',
#  'create art': 'dev_cb_sk_93',
#  'creating artwork': 'dev_cb_sk_93',
#  'create artworks': 'dev_cb_sk_93',
#  'make artwork': 'dev_cb_sk_93',
#  'produce artwork': 'dev_cb_sk_93',
#  'energies': 'dev_cb_sk_94',
#  'fuel': 'dev_cb_sk_94',
#  'energy': 'dev_cb_sk_94',
#  'draw up manuals': 'dev_cb_sk_95',
#  'manual writing': 'dev_cb_sk_95',
#  'write manuals': 'dev_cb_sk_95',
#  'draft manuals': 'dev_cb_sk_95',
#  'conduct ICT code review': 'dev_cb_sk_96',
#  'urban plan': 'dev_cb_sk_97',
#  'land use planning': 'dev_cb_sk_97',
#  'urban plans': 'dev_cb_sk_97',
#  'urban planning': 'dev_cb_sk_97',
#  'test materials': 'dev_cb_sk_98',
#  'check materials': 'dev_cb_sk_98',
#  'material test': 'dev_cb_sk_98',
#  'assess materials': 'dev_cb_sk_98',
#  'examine materials': 'dev_cb_sk_98',
#  'material testing': 'dev_cb_sk_98',
#  'material tests': 'dev_cb_sk_98',
#  'evaluate materials': 'dev_cb_sk_98',
#  'analyse materials': 'dev_cb_sk_98',
#  'interact using the telephone': 'dev_cb_sk_99',
#  'communicate by telephone': 'dev_cb_sk_99',
#  'communicate through telephone': 'dev_cb_sk_99',
#  'communicate by phone': 'dev_cb_sk_99',
#  'use the telephone': 'dev_cb_sk_99',
#  'plan research process': 'dev_cb_sk_100',
#  'health care administration': 'dev_cb_sk_101',
#  'healthcare administration': 'dev_cb_sk_101',
#  'Adobe Photoshop CC': 'dev_cb_sk_102',
#  'Adobe Photoshop Elements': 'dev_cb_sk_102',
#  'Adobe Photoshop': 'dev_cb_sk_102',
#  'backup data': 'dev_cb_sk_103',
#  'perform backups': 'dev_cb_sk_103',
#  'backup ICT system': 'dev_cb_sk_103',
#  'bake goods': 'dev_cb_sk_104',
#  'bake products': 'dev_cb_sk_104',
#  'bake a good': 'dev_cb_sk_104',
#  'baking goods': 'dev_cb_sk_104',
#  'bake': 'dev_cb_sk_104',
#  'preventative methods in healthcare of elderly people': 'dev_cb_sk_105',
#  'geriatrics': 'dev_cb_sk_105',
#  'geriatric medicine': 'dev_cb_sk_105',
#  'health care of elderly people': 'dev_cb_sk_105',
#  'treatment of conditions occurring in old age': 'dev_cb_sk_105',
#  'pharmacotherapy': 'dev_cb_sk_106',
#  'treatment using pharmaceutical drugs': 'dev_cb_sk_106',
#  'drug therapy': 'dev_cb_sk_106',
#  'therapy using pharmaceutical drugs': 'dev_cb_sk_106',
#  'operate haul truck': 'dev_cb_sk_107',
#  'operation of dump truck': 'dev_cb_sk_107',
#  'operating haul truck': 'dev_cb_sk_107',
#  'dump truck operation': 'dev_cb_sk_107',
#  'operating of dump truck': 'dev_cb_sk_107',
#  'operating dumper': 'dev_cb_sk_107',
#  'operate dump truck': 'dev_cb_sk_107',
#  'operate truck': 'dev_cb_sk_107',
#  'operate dumper': 'dev_cb_sk_107',
#  'operating dump truck': 'dev_cb_sk_107',
#  'operating truck': 'dev_cb_sk_107',
#  'gradual development': 'dev_cb_sk_108',
#  'incremental development': 'dev_cb_sk_108',
#  'shipment of cargo': 'dev_cb_sk_109',
#  'transportation of freight': 'dev_cb_sk_109',
#  'cargo transport': 'dev_cb_sk_109',
#  'transportation of cargo': 'dev_cb_sk_109',
#  'freight shipment': 'dev_cb_sk_109',
#  'cargo and freight industry': 'dev_cb_sk_109',
#  'cargo and logistics industry': 'dev_cb_sk_109',
#  'cargo shipping': 'dev_cb_sk_109',
#  'cargo industry': 'dev_cb_sk_109',
#  'freight transport': 'dev_cb_sk_109',
#  'consult on learning methods': 'dev_cb_sk_110',
#  'confer on learning methods': 'dev_cb_sk_110',
#  'advising on learning methods': 'dev_cb_sk_110',
#  'make recommendations on learning methods': 'dev_cb_sk_110',
#  'advise on learning methods': 'dev_cb_sk_110',
#  'advises on learning methods': 'dev_cb_sk_110',
#  'social and preventative medicine': 'dev_cb_sk_111',
#  'preventative and social medicine': 'dev_cb_sk_111',
#  'community medicine': 'dev_cb_sk_111',
#  'community health': 'dev_cb_sk_111',
#  'efficient electricity use': 'dev_cb_sk_112',
#  'electricity consumption': 'dev_cb_sk_112',
#  'consuming electricity': 'dev_cb_sk_112',
#  'efficient use of electricity': 'dev_cb_sk_112',
#  'conservation of electricity': 'dev_cb_sk_112',
#  'consumption of electricity': 'dev_cb_sk_112',
#  'electricity conservation': 'dev_cb_sk_112',
#  'consuming of electricity': 'dev_cb_sk_112',
#  'work out the structure of prototypes': 'dev_cb_sk_113',
#  'design prototypes': 'dev_cb_sk_113',
#  'construct prototypes': 'dev_cb_sk_113',
#  'conceive prototypes': 'dev_cb_sk_113',
#  'create preproduction models': 'dev_cb_sk_113',
#  'draft prototypes': 'dev_cb_sk_113',
#  'create prototypes': 'dev_cb_sk_113',
#  'designing prototypes': 'dev_cb_sk_113',
#  'develop prototypes': 'dev_cb_sk_113',
#  'legal inquiries': 'dev_cb_sk_114',
#  'judicial inquiries': 'dev_cb_sk_114',
#  'judicial probing': 'dev_cb_sk_114',
#  'legal investigations': 'dev_cb_sk_114',
#  'legal research': 'dev_cb_sk_114',
#  'judicial investigations': 'dev_cb_sk_114',
#  'legal probing': 'dev_cb_sk_114',
#  'judicial analysis': 'dev_cb_sk_114',
#  'legal analysis': 'dev_cb_sk_114',
#  'e-commerce arrangement': 'dev_cb_sk_115',
#  'e-commerce systems': 'dev_cb_sk_115',
#  'e commerce structure': 'dev_cb_sk_115',
#  'e commerce organisation': 'dev_cb_sk_115',
#  'e-commercial systems': 'dev_cb_sk_115',
#  'e-commercial system': 'dev_cb_sk_115',
#  'e-commerce system': 'dev_cb_sk_115',
#  'e-commerce scheme': 'dev_cb_sk_115',
#  'financial department methods': 'dev_cb_sk_116',
#  'financial processes': 'dev_cb_sk_116',
#  'financial department procedures': 'dev_cb_sk_116',
#  'financial department processes': 'dev_cb_sk_116',
#  'finance department processes': 'dev_cb_sk_116',
#  'financial department process': 'dev_cb_sk_116',
#  'explain tour highlights to visitors': 'dev_cb_sk_117',
#  'inform tour site visitors': 'dev_cb_sk_117',
#  'describe tour points of interest to visitors': 'dev_cb_sk_117',
#  'inform tour visitors at sites': 'dev_cb_sk_117',
#  'inform visitors at tour sites': 'dev_cb_sk_117',
#  'electric charge': 'dev_cb_sk_118',
#  'electric current': 'dev_cb_sk_118',
#  'electricity charge': 'dev_cb_sk_118',
#  'electric service': 'dev_cb_sk_118',
#  'electric flow': 'dev_cb_sk_118',
#  'electric voltage': 'dev_cb_sk_118',
#  'electricity voltage': 'dev_cb_sk_118',
#  'electricity service': 'dev_cb_sk_118',
#  'electricity flow': 'dev_cb_sk_118',
#  'radio spectrum': 'dev_cb_sk_119',
#  'electromagnetic frequencies': 'dev_cb_sk_119',
#  'electromagnetic wavelength': 'dev_cb_sk_119',
#  'radio frequencies': 'dev_cb_sk_119',
#  'electromagnetic levels': 'dev_cb_sk_119',
#  'electromagnetic spectrum': 'dev_cb_sk_119',
#  'radio wavelength': 'dev_cb_sk_119',
#  'storage of patient records': 'dev_cb_sk_120',
#  'compilation of patient records': 'dev_cb_sk_120',
#  'patient record storage': 'dev_cb_sk_120',
#  'patient data storage': 'dev_cb_sk_120',
#  'compilation of patient data': 'dev_cb_sk_120',
#  'empathise with healthcare users': 'dev_cb_sk_121',
#  'empathise with the health-care user': 'dev_cb_sk_121',
#  'sympathise with the healthcare user': 'dev_cb_sk_121',
#  'be understanding of the health-care user': 'dev_cb_sk_121',
#  'be understanding of the patient': 'dev_cb_sk_121',
#  'empathize  with the healthcare user': 'dev_cb_sk_121',
#  'empathise with the healthcare user': 'dev_cb_sk_121',
#  'sympathise with the patient': 'dev_cb_sk_121',
#  'empathise with patients': 'dev_cb_sk_121',
#  'clean building floors': 'dev_cb_sk_122',
#  'cleaning building floors': 'dev_cb_sk_122',
#  'clean floors of building': 'dev_cb_sk_122',
#  'tidy building floors': 'dev_cb_sk_122',
#  'clean buildings floors': 'dev_cb_sk_122',
#  'clean up building floors': 'dev_cb_sk_122',
#  'clean building floor': 'dev_cb_sk_122',
#  'install directory services': 'dev_cb_sk_123',
#  'distributed directory information services': 'dev_cb_sk_123',
#  'active directory': 'dev_cb_sk_123',
#  'directory service': 'dev_cb_sk_123',
#  'supervision of work': 'dev_cb_sk_124',
#  'giving direction to subordinates': 'dev_cb_sk_124',
#  'give direction to subordinates': 'dev_cb_sk_124',
#  'supervising work': 'dev_cb_sk_124',
#  'direction of subordinates': 'dev_cb_sk_124',
#  'work supervision': 'dev_cb_sk_124',
#  'direct subordinates': 'dev_cb_sk_124',
#  'supervising of work': 'dev_cb_sk_124',
#  'supervise work': 'dev_cb_sk_124',
#  'directing subordinates': 'dev_cb_sk_124',
#  'help staff': 'dev_cb_sk_125',
#  'guide staff': 'dev_cb_sk_125',
#  'support staff': 'dev_cb_sk_125',
#  'direct co-workers': 'dev_cb_sk_125',
#  'inform staff': 'dev_cb_sk_125',
#  'help co-workers': 'dev_cb_sk_125',
#  'support co-workers': 'dev_cb_sk_125',
#  'direct staff': 'dev_cb_sk_125',
#  'inform co-workers': 'dev_cb_sk_125',
#  'prescribe physical exercises': 'dev_cb_sk_126',
#  'assist in performing physical training': 'dev_cb_sk_126',
#  'assist in performing physical exercises': 'dev_cb_sk_126',
#  'assist in performing physical activities': 'dev_cb_sk_126',
#  'help in performing physical exercise': 'dev_cb_sk_126',
#  'assist in performing physical activity': 'dev_cb_sk_126',
#  'perform physical exercises': 'dev_cb_sk_126',
#  'help in performing physical exercises': 'dev_cb_sk_126',
#  'assist in operating physical exercise': 'dev_cb_sk_126',
#  'assist in operating physical exercises': 'dev_cb_sk_126',
#  'assist in performing physical trainings': 'dev_cb_sk_126',
#  'designing scale models': 'dev_cb_sk_127',
#  'arrange scale models': 'dev_cb_sk_127',
#  'design a scale model': 'dev_cb_sk_127',
#  'scale model planning': 'dev_cb_sk_127',
#  'design scale models': 'dev_cb_sk_127',
#  'plan scale models': 'dev_cb_sk_127',
#  'develop scale models': 'dev_cb_sk_127',
#  'interact with clients': 'dev_cb_sk_128',
#  'communicate with customers': 'dev_cb_sk_128',
#  'supply customer service': 'dev_cb_sk_128',
#  'engage with customers': 'dev_cb_sk_128',
#  'talk with customers': 'dev_cb_sk_128',
#  'interact with customers': 'dev_cb_sk_128',
#  'provide customer service': 'dev_cb_sk_128',
#  'communicate with clients': 'dev_cb_sk_128',
#  'respond to customer requests': 'dev_cb_sk_128',
#  'creative solutions': 'dev_cb_sk_129',
#  'creative problem solving solutions': 'dev_cb_sk_129',
#  'design thinking': 'dev_cb_sk_129',
#  'prepare speciality coffee': 'dev_cb_sk_130',
#  'prepare specialised coffee': 'dev_cb_sk_130',
#  'prepare specialized  coffee': 'dev_cb_sk_130',
#  'prepare special coffee': 'dev_cb_sk_130',
#  'offer particular gourmet coffees': 'dev_cb_sk_130',
#  'prepare artisanal coffee': 'dev_cb_sk_130',
#  'document interview': 'dev_cb_sk_131',
#  'write down interviews': 'dev_cb_sk_131',
#  'record interviews': 'dev_cb_sk_131',
#  'document interviews': 'dev_cb_sk_131',
#  'documenting interviews': 'dev_cb_sk_131',
#  'register interviews': 'dev_cb_sk_131',
#  'cascading style sheets': 'dev_cb_sk_132',
#  'SMIL Timesheets': 'dev_cb_sk_132',
#  'CSS': 'dev_cb_sk_132',
#  'Document Style Semantics and Specification Language': 'dev_cb_sk_132',
#  'Formatted Output Specification Instance': 'dev_cb_sk_132',
#  'style sheet languages': 'dev_cb_sk_132',
#  'Extensible Stylesheet Language': 'dev_cb_sk_132',
#  'compose headlines': 'dev_cb_sk_133',
#  'writing headlines': 'dev_cb_sk_133',
#  'write headline': 'dev_cb_sk_133',
#  'create headlines': 'dev_cb_sk_133',
#  'write headlines': 'dev_cb_sk_133',
#  'characteristics of a  product': 'dev_cb_sk_134',
#  'product characteristics': 'dev_cb_sk_134',
#  'attributes of products': 'dev_cb_sk_134',
#  'characteristic of a product': 'dev_cb_sk_134',
#  'characteristics of products': 'dev_cb_sk_134',
#  'components of products': 'dev_cb_sk_134',
#  'qualities of products': 'dev_cb_sk_134',
#  'aspects of products': 'dev_cb_sk_134',
#  'apply strategic thinking techniques': 'dev_cb_sk_135',
#  'apply strategic thinking': 'dev_cb_sk_135',
#  'think strategically': 'dev_cb_sk_135',
#  'apply techniques for strategic thinking': 'dev_cb_sk_135',
#  'move strategically': 'dev_cb_sk_135',
#  'manage inventories': 'dev_cb_sk_136',
#  'regulate inventory': 'dev_cb_sk_136',
#  'supervise inventory': 'dev_cb_sk_136',
#  'oversee inventory': 'dev_cb_sk_136',
#  'manage inventory': 'dev_cb_sk_136',
#  'maintain inventory': 'dev_cb_sk_136',
#  'managing an inventory': 'dev_cb_sk_136',
#  'manage an inventory': 'dev_cb_sk_136',
#  'mixing reagents': 'dev_cb_sk_137',
#  'formulate treating materials': 'dev_cb_sk_137',
#  'formulation of treating materials': 'dev_cb_sk_137',
#  'mix chemicals': 'dev_cb_sk_137',
#  'formulating treating materials': 'dev_cb_sk_137',
#  'mix catalysts': 'dev_cb_sk_137',
#  'mix treating materials': 'dev_cb_sk_137',
#  'mix reagents': 'dev_cb_sk_137',
#  'treating materials mixing': 'dev_cb_sk_137',
#  'mixing catalysts': 'dev_cb_sk_137',
#  'treating material mixing': 'dev_cb_sk_137',
#  'mixing chemicals': 'dev_cb_sk_137',
#  'scaffolding elements': 'dev_cb_sk_138',
#  'base plate': 'dev_cb_sk_138',
#  'pole': 'dev_cb_sk_138',
#  'ledges': 'dev_cb_sk_138',
#  'scaffold components': 'dev_cb_sk_138',
#  'components of scaffolding': 'dev_cb_sk_138',
#  'board': 'dev_cb_sk_138',
#  'scaffolding components': 'dev_cb_sk_138',
#  'transom': 'dev_cb_sk_138',
#  'standard': 'dev_cb_sk_138',
#  'tie': 'dev_cb_sk_138',
#  'scaffolding parts': 'dev_cb_sk_138',
#  'semiconductors': 'dev_cb_sk_139',
#  'types of IC': 'dev_cb_sk_139',
#  'types of semiconductors': 'dev_cb_sk_139',
#  'semi-conductor types': 'dev_cb_sk_139',
#  'types of integrated circuits': 'dev_cb_sk_139',
#  'semiconductor types': 'dev_cb_sk_139',
#  'typology of integrated circuits': 'dev_cb_sk_139',
#  'typology of ICs': 'dev_cb_sk_139',
#  'Ics': 'dev_cb_sk_139',
#  'integrated circuit types': 'dev_cb_sk_139',
#  'types of ICs': 'dev_cb_sk_139',
#  'types of semi-conductors': 'dev_cb_sk_139',
#  'types of integrated circuit': 'dev_cb_sk_139',
#  'semi-conductors': 'dev_cb_sk_139',
#  'typology of semi-conductors': 'dev_cb_sk_139',
#  'IC types': 'dev_cb_sk_139',
#  'typology of semiconductors': 'dev_cb_sk_139',
#  'ICT system upgrade': 'dev_cb_sk_140',
#  'manage changes in ICT system': 'dev_cb_sk_140',
#  'create a bond with the media': 'dev_cb_sk_141',
#  'establish a media relationship': 'dev_cb_sk_141',
#  'develop a relationship with the media': 'dev_cb_sk_141',
#  'establish relationship with the media': 'dev_cb_sk_141',
#  'radiology': 'dev_cb_sk_142',
#  'interventional radiology': 'dev_cb_sk_142',
#  'clinical radiology': 'dev_cb_sk_142',
#  'medical imaging techniques': 'dev_cb_sk_142',
#  'packaging purchases in bags': 'dev_cb_sk_143',
#  'load purchases in bags': 'dev_cb_sk_143',
#  'package purchases in bags': 'dev_cb_sk_143',
#  'bundle purchases in bags': 'dev_cb_sk_143',
#  'parcel up purchases in bags': 'dev_cb_sk_143',
#  'package a purchase in a bag': 'dev_cb_sk_143',
#  'package purchases in a bag': 'dev_cb_sk_143',
#  'stow purchases in bags': 'dev_cb_sk_143',
#  'develop new product': 'dev_cb_sk_144',
#  'design new products': 'dev_cb_sk_144',
#  'develop new products': 'dev_cb_sk_144',
#  'produce new products': 'dev_cb_sk_144',
#  'create new products': 'dev_cb_sk_144',
#  'generate new products': 'dev_cb_sk_144',
#  'developing new products': 'dev_cb_sk_144',
#  'develop products': 'dev_cb_sk_144',
#  'oversee information access aids': 'dev_cb_sk_145',
#  'manage information access aids': 'dev_cb_sk_145',
#  'manage info access aids': 'dev_cb_sk_145',
#  'manage aids for information access': 'dev_cb_sk_145',
#  'maintain information access aids': 'dev_cb_sk_145',
#  'supervise information access aids': 'dev_cb_sk_145',
#  'copyrights': 'dev_cb_sk_146',
#  'rights': 'dev_cb_sk_146',
#  'patents': 'dev_cb_sk_146',
#  'administer returns': 'dev_cb_sk_147',
#  'conduct returns': 'dev_cb_sk_147',
#  'handling a return': 'dev_cb_sk_147',
#  'handling returns': 'dev_cb_sk_147',
#  'deal with returns': 'dev_cb_sk_147',
#  'accept returns': 'dev_cb_sk_147',
#  'handle a return': 'dev_cb_sk_147',
#  'handle returns': 'dev_cb_sk_147',
#  'task management': 'dev_cb_sk_148',
#  'manage tasking': 'dev_cb_sk_148',
#  'plan tasks': 'dev_cb_sk_148',
#  'manage task scheduling': 'dev_cb_sk_148',
#  'organize tasks': 'dev_cb_sk_148',
#  'manage schedule of tasks': 'dev_cb_sk_148',
#  ...}

# %% [markdown]
# Load simple embedding model:

# %%
model = SentenceTransformer("all-MiniLM-L6-v2", token=False)
# Out:
# modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/10.5k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Xet Storage is enabled for this repo, but the 'hf_xet' package is not installed. Falling back to regular HTTP download. For better performance, install the package with: `pip install huggingface_hub[hf_xet]` or `pip install hf_xet`
# model.safetensors:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
c

# %%
tracker = EmissionsTracker()
tracker.start_task("all-MiniLM-L6-v2")

# %% [markdown]
# Encode queries and corpus elements:

# %%
query_embeddings = model.encode(queries_texts, convert_to_tensor=True)
corpus_embeddings = model.encode(corpus_texts, convert_to_tensor=True)

# %% [markdown]
# Compute similarities

# %%
similarities = util.cos_sim(query_embeddings, corpus_embeddings).cpu().numpy()
emissions = tracker.stop_task("all-MiniLM-L6-v2")

# %% [markdown]
# ## Prepare submission file

# %% [markdown]
# The submissions must follow the TREC Run File format, including headers in the output file. This means that the fle have 6 space-spearated columns per line, with following information:
#
# - q_id: Query ID.
# - Q0: A constant identifier, usually "Q0".
# - doc_id: ID of the retrieved document.
# - rank: Position of the document in the ranking.
# - score: Relevance score assigned by the model.
# - tag: Experiment name

# %%
import numpy as np
results = []
results_name = []

for q_idx, q_id in enumerate(queries_ids):
    sorted_indices = np.argsort(-similarities[q_idx])
    used_doc_ids = set()
    rank_counter = 0
    for c_idx in sorted_indices:  # Consider the full list.
        doc_id = corpus_ids[c_idx]
        # If doc_id was already processed, go to the next one.
        if doc_id in used_doc_ids:
            continue
        used_doc_ids.add(doc_id)
        rank_counter += 1

        query_name = map_queries[q_id]
        doc_name = corpus_texts[c_idx]
        score = similarities[q_idx, c_idx]

        results.append(f"{q_id} Q0 {doc_id} {rank_counter} {score:.4f} baseline_model")
        results_name.append(f"{query_name} Q0 {doc_name} {rank_counter} {score:.4f} baseline_model")

# %% [markdown]
# The list has this structure

# %% [markdown]
# Let's save the list as a file:

# %%
result_baseline_taskB = os.path.join(taskB_results_path, "evaluation_baseline_taskB.trec")
with open(result_baseline_taskB, "w", encoding="utf-8") as f:
    f.write("\n".join(results))

emissions_path = os.path.join(taskB_evaluations_path, "emissions.json")
json.dump(dict(emissions.values), open(emissions_path, "w"), ensure_ascii=False, indent=4)

# %% [markdown]
# ## Evaluation

# %% [markdown]
# For the evaluation, we will use the official [TalentCLEF evaluation script](https://github.com/TalentCLEF/talentclef25_evaluation_script), which uses the Ranx library under the hood.
#
# First, clone the repo and install the requirements file:

# %%
# !git clone https://github.com/TalentCLEF/talentclef25_evaluation_script.git
# !pip install -r /content/talentclef25_evaluation_script/requirements.txt
# Out:
# Cloning into 'talentclef25_evaluation_script'...
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# remote: Enumerating objects: 27, done.
# remote: Counting objects: 100% (27/27), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 27 (delta 10), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (27/27), 10.10 KiB | 5.05 MiB/s, done.
# Resolving deltas: 100% (10/10), done.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ERROR: Could not open requirements file: [Errno 2] No such file or directory: '/content/talentclef25_evaluation_script/requirements.txt'

# %% [markdown]
# Then, select the Qrels file and the Run file to perform the evaluation.

# %%
qrels_file = os.path.join(taskB_path, "validation", "qrels.tsv")
run_file = os.path.join(taskB_results_path, "evaluation_baseline_taskB.trec")

# %%
command = ["python", "talentclef25_evaluation_script/talentclef_evaluate.py", "--qrels", qrels_file, "--run", run_file]
result = subprocess.run(command, capture_output=True, text=True)
print(result.stdout)
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)

# %%
# !python talentclef25_evaluation_script/talentclef_evaluate.py --qrels ~/Documents/projects/data/ir_data/talent_clef/TaskB/validation/qrels.tsv --run ~/Documents/projects/data/ir_data/talent_clef/TaskB/results/evaluation_baseline_taskB.tre

# %%
#model.save(taskB_models_path)
